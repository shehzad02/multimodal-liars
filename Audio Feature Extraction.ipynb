# %%
##first get audio from video

# %%
##pip install "numpy<1.24.0".
#!pip install numpy==1.21.0

# %%
#pip install ffmpeg moviepy

# %%
#pip install librosa

# %%
import moviepy.editor as mp

# %%
my_clip = mp.VideoFileClip(r"video_clips/lie/trial_lie_001.mp4")

# %%
my_clip

# %%
my_clip.audio.write_audiofile(r"audio_clips/lie/trial_lie_001.mp3")
# Out:
# MoviePy - Writing audio in audio_clips/lie/trial_lie_001.mp3
# MoviePy - Done.

# %%
# read audio files
import librosa
import numpy as np
import matplotlib.pyplot as plt

# %%
signal, sample_rate = librosa.load('./audio_clips/lie/trial_lie_001.mp3')

# %%
# plot audio file in time domain
plt.figure(1)
librosa.display.waveshow(y=signal, sr=sample_rate)
plt.title('Lie Audio File in Time Domain')
plt.xlabel('Time / second')
plt.ylabel('Amplitude')
plt.show()

# %%
# plot audio files in frequency domain
k = np.arange(len(signal))
T = len(signal)/sample_rate
freq = k/T

DATA_0 = np.fft.fft(signal)
abs_DATA_0 = abs(DATA_0)
plt.figure(2)
plt.plot(freq, abs_DATA_0)
plt.title('Lie Audio File in Frequency Domain')

plt.xlabel("Frequency / Hz")
plt.ylabel("Amplitude / dB")
plt.xlim([0, 1000])
plt.show()

# %%
# plot the time-frequency variation of the audio
D = librosa.stft(signal)  # STFT of y
S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
plt.figure(3)
#librosa.display.specshow(S_db, x_axis='time', y_axis='log')
librosa.display.specshow(S_db, x_axis='time', y_axis='log', backend='scipy')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 # plot the time-frequency variation of the audio
# ----> 2 D = librosa.stft(signal)  # STFT of y
#       3 S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)
#       4 plt.figure(3)
#
# File ~\anaconda3\envs\audio processing\lib\site-packages\librosa\core\spectrum.py:333, in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode, out)
#     330     dtype = util.dtype_r2c(y.dtype)
#     332 # Window the time series.
# --> 333 y_frames = util.frame(y[..., start:], frame_length=n_fft, hop_length=hop_length)
#     335 # Pre-allocate the STFT matrix
#     336 shape = list(y_frames.shape)
#
# File ~\anaconda3\envs\audio processing\lib\site-packages\librosa\util\utils.py:222, in frame(x, frame_length, hop_length, axis, writeable, subok)
#     219 x_shape_trimmed[axis] -= frame_length - 1
#     221 out_shape = tuple(x_shape_trimmed) + tuple([frame_length])
# --> 222 xw = as_strided(
#     223     x, strides=out_strides, shape=out_shape, subok=subok, writeable=writeable
#     224 )
#     226 if axis < 0:
#     227     target_axis = axis - 1
#
# File ~\anaconda3\envs\audio processing\lib\site-packages\numpy\lib\stride_tricks.py:105, in as_strided(x, shape, strides, subok, writeable)
#     102 if strides is not None:
#     103     interface['strides'] = tuple(strides)
# --> 105 array = np.asarray(DummyArray(interface, base=x))
#     106 # The route via `__interface__` does not preserve structured
#     107 # dtypes. Since dtype should remain unchanged, we set it explicitly.
#     108 array.dtype = x.dtype
#
# ValueError: array is too big; `arr.size * arr.dtype.itemsize` is larger than the maximum possible size.
